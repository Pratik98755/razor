# %%
import streamlit as st
user = st.session_state.user
# Out:
# 2026-08-22 12:34:20.566 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-22 12:34:20.567 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:731, in SessionState.__getitem__(self, key)
#     730 try:
# --> 731     base_value = self._getitem(widget_id, key)
#     732     return (
#     733         apply_presenter(self, widget_id, base_value)
#     734         if widget_id is not None
#     735         else base_value
#     736     )
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:784, in SessionState._getitem(self, widget_id, user_key)
#     783 # We'll never get here
# --> 784 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:130, in SessionStateProxy.__getattr__(self, key)
#     129 try:
# --> 130     return self[key]
#     131 except KeyError:
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:101, in SessionStateProxy.__getitem__(self, key)
#     100 require_valid_user_key(key)
# --> 101 return get_session_state()[key]
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\safe_session_state.py:104, in SafeSessionState.__getitem__(self, key)
#     103 with self._lock:
# --> 104     return self._state[key]
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:738, in SessionState.__getitem__(self, key)
#     737 except KeyError:
# --> 738     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "user". Did you forget to initialize it? More info: https://docs.streamlit.io/develop/concepts/architecture/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import streamlit as st
# ----> 2 user = st.session_state.user
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:132, in SessionStateProxy.__getattr__(self, key)
#     130     return self[key]
#     131 except KeyError:
# --> 132     raise AttributeError(_missing_attr_error_message(key))
#
# AttributeError: st.session_state has no attribute "user". Did you forget to initialize it? More info: https://docs.streamlit.io/develop/concepts/architecture/session-state#initialization

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model = "openai/gpt-oss-20b", streaming = True)

# %%
import streamlit as st
st.session_state.product_draft
# Out:
# 2026-08-22 19:52:40.296 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:731, in SessionState.__getitem__(self, key)
#     730 try:
# --> 731     base_value = self._getitem(widget_id, key)
#     732     return (
#     733         apply_presenter(self, widget_id, base_value)
#     734         if widget_id is not None
#     735         else base_value
#     736     )
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:784, in SessionState._getitem(self, widget_id, user_key)
#     783 # We'll never get here
# --> 784 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:130, in SessionStateProxy.__getattr__(self, key)
#     129 try:
# --> 130     return self[key]
#     131 except KeyError:
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:101, in SessionStateProxy.__getitem__(self, key)
#     100 require_valid_user_key(key)
# --> 101 return get_session_state()[key]
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\safe_session_state.py:104, in SafeSessionState.__getitem__(self, key)
#     103 with self._lock:
# --> 104     return self._state[key]
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:738, in SessionState.__getitem__(self, key)
#     737 except KeyError:
# --> 738     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "product_draft". Did you forget to initialize it? More info: https://docs.streamlit.io/develop/concepts/architecture/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import streamlit as st
# ----> 2 st.session_state.product_draft
#
# File d:\razor\agent\.venv\Lib\site-packages\streamlit\runtime\state\session_state_proxy.py:132, in SessionStateProxy.__getattr__(self, key)
#     130     return self[key]
#     131 except KeyError:
# --> 132     raise AttributeError(_missing_attr_error_message(key))
#
# AttributeError: st.session_state has no attribute "product_draft". Did you forget to initialize it? More info: https://docs.streamlit.io/develop/concepts/architecture/session-state#initialization
